# %%
import os
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline  

import warnings
warnings.filterwarnings("ignore")

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data.dataset import Dataset
from torch.utils.data import random_split

from cifar_model_arch.densenet import DenseNet121
from cifar_model_arch.efficientnet import EfficientNetB0
from cifar_model_arch.resnet import ResNet18
from cifar_model_arch.swin import swin_s
from cifar_model_arch.vit import ViT

# %%
train_transform = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.RandomRotation(15),
            transforms.ColorJitter(0.05, 0.05, 0.05, 0.05),
            transforms.ToTensor(),
        ])

test_transform = transforms.Compose([
    # transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                            download=True, transform=test_transform)
dev_dataset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                           download=True, transform=train_transform)

generator = torch.Generator().manual_seed(42)
train_dataset, val_dataset = random_split(dev_dataset, [0.8, 0.2], generator)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128,
                                          shuffle=True, num_workers=8)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=128,
                                          shuffle=False, num_workers=8)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=128,
                                          shuffle=False, num_workers=8)

# %%
def train_classifer_epoch(net, trainloader,
                optimizer, device):
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    loss_func = nn.CrossEntropyLoss()
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        targets = targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs.to(device))
        loss = loss_func(outputs, targets)
        loss.backward()
        optimizer.step()
        predicted = outputs.argmax(dim=1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        train_loss += loss.item()
    train_loss = train_loss/(batch_idx+1)
    train_acc = correct/total
    return train_acc, train_loss

def test_classifer_accuracy(net, testloader, device):
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    loss_func = nn.CrossEntropyLoss()
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            targets = targets.to(device)
            outputs = net(inputs.to(device))
            loss = loss_func(outputs, targets)
            test_loss += loss.item()
            predicted = outputs.argmax(dim=1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    test_acc = correct/total
    test_loss = test_loss/(batch_idx+1)
    return test_acc, test_loss

def get_preds_labels(net, testloader, device):
    net.eval()
    preds = []
    true_labels = []
    sigmoid = nn.Sigmoid()
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            outputs = net(inputs.to(device))
            predicted = torch.softmax(outputs, dim=1).detach()
            preds.append(predicted)
            true_labels.append(targets)
        preds = torch.cat(preds)
        true_labels = torch.cat(true_labels)
    return preds.cpu().numpy(), true_labels.cpu().numpy()

# %%
def train(net, epochs, trainloader, validloader,
          seed, save_path, device):
    best_acc = -np.inf
    test_acc_history = []
    # optimizer = optim.SGD(net.parameters(), momentum=0.9,
    #                       lr=0.1, weight_decay=5e-4, )
    # lr_scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[150, 250])
    optimizer = optim.AdamW(net.parameters(), lr=5e-5)
    lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    for epoch in range(epochs):
        train_acc, train_loss  = train_classifer_epoch(net, trainloader, optimizer,
                                                      device)
        test_acc, test_loss = test_classifer_accuracy(net, validloader, device)
        test_acc_history.append(test_acc)
        print(f'epoch ({epoch+1})| Train loss {round(train_loss, 2)}| Train accuracy {round(train_acc, 2)}| Test accuracy {round(test_acc, 2)}| Test loss {round(test_loss, 2)}')
        if best_acc < test_acc:
            print('Saving model...')
            model_state = {'net': net.state_dict(),
                           'opti': optimizer.state_dict(),
                           'epoch': epoch,
                           'seed': seed,
                           'acc': test_acc,'epoch': epoch,
                           'test_acc_history':test_acc_history}
            torch.save(model_state, save_path)
            best_acc = test_acc
        lr_scheduler.step()

# %%
# net = swin_s(num_classes=10)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 'resnet18' , 
# 'vit_b_16'
# 'swin_s', - one is missing
# 'efficientnet_b2',
seed = 61
torch.random.manual_seed(seed)

# model =  ViT(
#     image_size = 32,
#     patch_size = 4,
#     num_classes = 10,
#     dim = 384,
#     depth = 7,
#     heads = 12,
#     mlp_dim = 384*3,
#     dropout = 0.1,
#     emb_dropout = 0
# ).to(device)

model = swin_s().to(device)



train(model, 350, train_loader, test_loader, seed,
  f'./models/cifar10/Swin_1.ckpt', device)
# Out:
# epoch (1)| Train loss 2.11| Train accuracy 0.26| Test accuracy 0.36| Test loss 1.78
# Saving model...
# epoch (2)| Train loss 1.64| Train accuracy 0.4| Test accuracy 0.44| Test loss 1.53
# Saving model...
# epoch (3)| Train loss 1.42| Train accuracy 0.48| Test accuracy 0.49| Test loss 1.39
# Saving model...
# epoch (4)| Train loss 1.29| Train accuracy 0.53| Test accuracy 0.55| Test loss 1.25
# Saving model...
# epoch (5)| Train loss 1.2| Train accuracy 0.57| Test accuracy 0.6| Test loss 1.12
# Saving model...
# epoch (6)| Train loss 1.11| Train accuracy 0.61| Test accuracy 0.6| Test loss 1.11
# Saving model...
# epoch (7)| Train loss 1.04| Train accuracy 0.63| Test accuracy 0.65| Test loss 1.0
# Saving model...
# epoch (8)| Train loss 1.0| Train accuracy 0.65| Test accuracy 0.64| Test loss 1.02
# epoch (9)| Train loss 0.94| Train accuracy 0.67| Test accuracy 0.65| Test loss 0.97
# Saving model...
# epoch (10)| Train loss 0.9| Train accuracy 0.68| Test accuracy 0.69| Test loss 0.89
# Saving model...
# epoch (11)| Train loss 0.86| Train accuracy 0.7| Test accuracy 0.7| Test loss 0.84
# Saving model...
# epoch (12)| Train loss 0.83| Train accuracy 0.71| Test accuracy 0.72| Test loss 0.81
# Saving model...
# epoch (13)| Train loss 0.8| Train accuracy 0.72| Test accuracy 0.72| Test loss 0.8
# Saving model...
# epoch (14)| Train loss 0.78| Train accuracy 0.72| Test accuracy 0.73| Test loss 0.76
# Saving model...
# epoch (15)| Train loss 0.75| Train accuracy 0.74| Test accuracy 0.74| Test loss 0.75
# Saving model...
# epoch (16)| Train loss 0.73| Train accuracy 0.74| Test accuracy 0.74| Test loss 0.73
# Saving model...
# epoch (17)| Train loss 0.7| Train accuracy 0.76| Test accuracy 0.75| Test loss 0.72
# Saving model...
# epoch (18)| Train loss 0.67| Train accuracy 0.76| Test accuracy 0.75| Test loss 0.71
# epoch (19)| Train loss 0.66| Train accuracy 0.77| Test accuracy 0.77| Test loss 0.66
# Saving model...
# epoch (20)| Train loss 0.64| Train accuracy 0.78| Test accuracy 0.77| Test loss 0.67
# Saving model...
# epoch (21)| Train loss 0.62| Train accuracy 0.78| Test accuracy 0.76| Test loss 0.67
# epoch (22)| Train loss 0.59| Train accuracy 0.79| Test accuracy 0.79| Test loss 0.62
# Saving model...
# epoch (23)| Train loss 0.59| Train accuracy 0.79| Test accuracy 0.78| Test loss 0.63
# epoch (24)| Train loss 0.57| Train accuracy 0.8| Test accuracy 0.79| Test loss 0.62
# Saving model...
# epoch (25)| Train loss 0.55| Train accuracy 0.8| Test accuracy 0.77| Test loss 0.68
# epoch (26)| Train loss 0.54| Train accuracy 0.81| Test accuracy 0.78| Test loss 0.65
# epoch (27)| Train loss 0.53| Train accuracy 0.81| Test accuracy 0.79| Test loss 0.59
# Saving model...
# epoch (28)| Train loss 0.51| Train accuracy 0.82| Test accuracy 0.8| Test loss 0.57
# Saving model...
# epoch (29)| Train loss 0.51| Train accuracy 0.82| Test accuracy 0.8| Test loss 0.58
# Saving model...
# epoch (30)| Train loss 0.49| Train accuracy 0.83| Test accuracy 0.8| Test loss 0.6
# epoch (31)| Train loss 0.48| Train accuracy 0.83| Test accuracy 0.82| Test loss 0.55
# Saving model...
# epoch (32)| Train loss 0.46| Train accuracy 0.84| Test accuracy 0.81| Test loss 0.58
# epoch (33)| Train loss 0.46| Train accuracy 0.84| Test accuracy 0.81| Test loss 0.56
# epoch (34)| Train loss 0.44| Train accuracy 0.84| Test accuracy 0.81| Test loss 0.55
# epoch (35)| Train loss 0.43| Train accuracy 0.85| Test accuracy 0.81| Test loss 0.55
# epoch (36)| Train loss 0.42| Train accuracy 0.85| Test accuracy 0.82| Test loss 0.53
# Saving model...
# epoch (37)| Train loss 0.41| Train accuracy 0.86| Test accuracy 0.82| Test loss 0.54
# epoch (38)| Train loss 0.4| Train accuracy 0.86| Test accuracy 0.82| Test loss 0.56
# epoch (39)| Train loss 0.39| Train accuracy 0.86| Test accuracy 0.82| Test loss 0.56
# epoch (40)| Train loss 0.39| Train accuracy 0.86| Test accuracy 0.82| Test loss 0.54
# Saving model...
# epoch (41)| Train loss 0.37| Train accuracy 0.87| Test accuracy 0.82| Test loss 0.53
# Saving model...
# epoch (42)| Train loss 0.36| Train accuracy 0.87| Test accuracy 0.83| Test loss 0.52
# Saving model...
# epoch (43)| Train loss 0.35| Train accuracy 0.88| Test accuracy 0.83| Test loss 0.53
# epoch (44)| Train loss 0.35| Train accuracy 0.88| Test accuracy 0.83| Test loss 0.51
# epoch (45)| Train loss 0.33| Train accuracy 0.88| Test accuracy 0.83| Test loss 0.54
# epoch (46)| Train loss 0.33| Train accuracy 0.89| Test accuracy 0.82| Test loss 0.54
# epoch (47)| Train loss 0.32| Train accuracy 0.89| Test accuracy 0.82| Test loss 0.56
# epoch (48)| Train loss 0.31| Train accuracy 0.89| Test accuracy 0.83| Test loss 0.52
# epoch (49)| Train loss 0.3| Train accuracy 0.89| Test accuracy 0.84| Test loss 0.52
# Saving model...
# epoch (50)| Train loss 0.3| Train accuracy 0.89| Test accuracy 0.82| Test loss 0.55
# epoch (51)| Train loss 0.29| Train accuracy 0.9| Test accuracy 0.83| Test loss 0.54
# epoch (52)| Train loss 0.28| Train accuracy 0.9| Test accuracy 0.84| Test loss 0.51
# Saving model...
# epoch (53)| Train loss 0.27| Train accuracy 0.9| Test accuracy 0.84| Test loss 0.52
# epoch (54)| Train loss 0.26| Train accuracy 0.91| Test accuracy 0.83| Test loss 0.53
# epoch (55)| Train loss 0.26| Train accuracy 0.91| Test accuracy 0.83| Test loss 0.53
# epoch (56)| Train loss 0.25| Train accuracy 0.91| Test accuracy 0.84| Test loss 0.54
# Saving model...
# epoch (57)| Train loss 0.24| Train accuracy 0.91| Test accuracy 0.84| Test loss 0.54
# Saving model...
# epoch (58)| Train loss 0.23| Train accuracy 0.92| Test accuracy 0.84| Test loss 0.53
# Saving model...
# epoch (59)| Train loss 0.23| Train accuracy 0.92| Test accuracy 0.84| Test loss 0.53
# epoch (60)| Train loss 0.22| Train accuracy 0.92| Test accuracy 0.84| Test loss 0.53
# Saving model...
# epoch (61)| Train loss 0.22| Train accuracy 0.92| Test accuracy 0.84| Test loss 0.53
# Saving model...
# epoch (62)| Train loss 0.21| Train accuracy 0.92| Test accuracy 0.84| Test loss 0.53
# epoch (63)| Train loss 0.21| Train accuracy 0.92| Test accuracy 0.84| Test loss 0.56
# epoch (64)| Train loss 0.21| Train accuracy 0.93| Test accuracy 0.84| Test loss 0.52
# epoch (65)| Train loss 0.2| Train accuracy 0.93| Test accuracy 0.85| Test loss 0.52
# Saving model...
# epoch (66)| Train loss 0.2| Train accuracy 0.93| Test accuracy 0.84| Test loss 0.56
# epoch (67)| Train loss 0.19| Train accuracy 0.93| Test accuracy 0.85| Test loss 0.53
# Saving model...
# epoch (68)| Train loss 0.18| Train accuracy 0.94| Test accuracy 0.85| Test loss 0.55
# epoch (69)| Train loss 0.17| Train accuracy 0.94| Test accuracy 0.85| Test loss 0.53
# Saving model...
# epoch (70)| Train loss 0.17| Train accuracy 0.94| Test accuracy 0.84| Test loss 0.56
# epoch (71)| Train loss 0.17| Train accuracy 0.94| Test accuracy 0.84| Test loss 0.54
# epoch (72)| Train loss 0.16| Train accuracy 0.94| Test accuracy 0.84| Test loss 0.57
# epoch (73)| Train loss 0.16| Train accuracy 0.94| Test accuracy 0.85| Test loss 0.52
# Saving model...
# epoch (74)| Train loss 0.15| Train accuracy 0.95| Test accuracy 0.85| Test loss 0.57
# epoch (75)| Train loss 0.16| Train accuracy 0.94| Test accuracy 0.85| Test loss 0.55
# epoch (76)| Train loss 0.14| Train accuracy 0.95| Test accuracy 0.85| Test loss 0.56
# epoch (77)| Train loss 0.14| Train accuracy 0.95| Test accuracy 0.85| Test loss 0.55
# epoch (78)| Train loss 0.14| Train accuracy 0.95| Test accuracy 0.85| Test loss 0.56
# epoch (79)| Train loss 0.14| Train accuracy 0.95| Test accuracy 0.85| Test loss 0.57
# epoch (80)| Train loss 0.13| Train accuracy 0.95| Test accuracy 0.84| Test loss 0.59
# epoch (81)| Train loss 0.13| Train accuracy 0.95| Test accuracy 0.85| Test loss 0.56
# Saving model...
# epoch (82)| Train loss 0.13| Train accuracy 0.96| Test accuracy 0.85| Test loss 0.57
# epoch (83)| Train loss 0.12| Train accuracy 0.96| Test accuracy 0.84| Test loss 0.61
# epoch (84)| Train loss 0.12| Train accuracy 0.96| Test accuracy 0.85| Test loss 0.58
# epoch (85)| Train loss 0.12| Train accuracy 0.96| Test accuracy 0.85| Test loss 0.58
# epoch (86)| Train loss 0.11| Train accuracy 0.96| Test accuracy 0.85| Test loss 0.6
# epoch (87)| Train loss 0.12| Train accuracy 0.96| Test accuracy 0.85| Test loss 0.57
# epoch (88)| Train loss 0.11| Train accuracy 0.96| Test accuracy 0.85| Test loss 0.59
# epoch (89)| Train loss 0.11| Train accuracy 0.96| Test accuracy 0.86| Test loss 0.56
# Saving model...
# epoch (90)| Train loss 0.1| Train accuracy 0.96| Test accuracy 0.85| Test loss 0.58
# epoch (91)| Train loss 0.1| Train accuracy 0.96| Test accuracy 0.85| Test loss 0.61
# epoch (92)| Train loss 0.1| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.61
# epoch (93)| Train loss 0.1| Train accuracy 0.96| Test accuracy 0.85| Test loss 0.62
# epoch (94)| Train loss 0.1| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.59
# epoch (95)| Train loss 0.09| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.64
# epoch (96)| Train loss 0.09| Train accuracy 0.97| Test accuracy 0.86| Test loss 0.59
# Saving model...
# epoch (97)| Train loss 0.1| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.6
# epoch (98)| Train loss 0.09| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.61
# epoch (99)| Train loss 0.09| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.62
# epoch (100)| Train loss 0.08| Train accuracy 0.97| Test accuracy 0.86| Test loss 0.6
# Saving model...
# epoch (101)| Train loss 0.09| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.62
# epoch (102)| Train loss 0.08| Train accuracy 0.97| Test accuracy 0.86| Test loss 0.61
# epoch (103)| Train loss 0.08| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.63
# epoch (104)| Train loss 0.08| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.61
# epoch (105)| Train loss 0.07| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.62
# epoch (106)| Train loss 0.08| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.6
# epoch (107)| Train loss 0.07| Train accuracy 0.97| Test accuracy 0.86| Test loss 0.63
# epoch (108)| Train loss 0.07| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.63
# epoch (109)| Train loss 0.07| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.62
# epoch (110)| Train loss 0.07| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.61
# epoch (111)| Train loss 0.07| Train accuracy 0.97| Test accuracy 0.85| Test loss 0.63
# epoch (112)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.61
# epoch (113)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.62
# epoch (114)| Train loss 0.07| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.64
# epoch (115)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.66
# epoch (116)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.65
# epoch (117)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.63
# epoch (118)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.65
# epoch (119)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.66
# epoch (120)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.67
# epoch (121)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.68
# epoch (122)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.66
# Saving model...
# epoch (123)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.68
# epoch (124)| Train loss 0.06| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.67
# epoch (125)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.67
# epoch (126)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.69
# epoch (127)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.67
# epoch (128)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.68
# epoch (129)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.68
# epoch (130)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.68
# epoch (131)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.7
# epoch (132)| Train loss 0.04| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.69
# epoch (133)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.85| Test loss 0.67
# epoch (134)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.85| Test loss 0.68
# epoch (135)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.67
# epoch (136)| Train loss 0.05| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.66
# Saving model...
# epoch (137)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.85| Test loss 0.73
# epoch (138)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.7
# epoch (139)| Train loss 0.04| Train accuracy 0.98| Test accuracy 0.86| Test loss 0.66
# epoch (140)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.67
# epoch (141)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.65
# Saving model...
# epoch (142)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.68
# epoch (143)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.71
# epoch (144)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.69
# epoch (145)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.72
# epoch (146)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.7
# epoch (147)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.85| Test loss 0.73
# epoch (148)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.71
# epoch (149)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.85| Test loss 0.74
# epoch (150)| Train loss 0.04| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.67
# epoch (151)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.73
# epoch (152)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.7
# epoch (153)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.85| Test loss 0.71
# epoch (154)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.76
# epoch (155)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.71
# epoch (156)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.71
# epoch (157)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.73
# epoch (158)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.74
# epoch (159)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.73
# epoch (160)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.76
# epoch (161)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.72
# epoch (162)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.74
# epoch (163)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.73
# epoch (164)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.85| Test loss 0.76
# epoch (165)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.74
# epoch (166)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.75
# epoch (167)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.72
# epoch (168)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.73
# epoch (169)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.85| Test loss 0.75
# epoch (170)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.7
# epoch (171)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.72
# epoch (172)| Train loss 0.03| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.74
# epoch (173)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.73
# epoch (174)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.72
# epoch (175)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.74
# epoch (176)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.73
# Saving model...
# epoch (177)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.75
# epoch (178)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.87| Test loss 0.71
# Saving model...
# epoch (179)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.72
# epoch (180)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.75
# epoch (181)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.74
# epoch (182)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.85| Test loss 0.77
# epoch (183)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.75
# epoch (184)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.75
# epoch (185)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.76
# epoch (186)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.76
# epoch (187)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.76
# epoch (188)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.76
# epoch (189)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.87| Test loss 0.73
# epoch (190)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.77
# epoch (191)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.87| Test loss 0.73
# epoch (192)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.75
# epoch (193)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.87| Test loss 0.77
# epoch (194)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.87| Test loss 0.75
# epoch (195)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.77
# epoch (196)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.77
# epoch (197)| Train loss 0.02| Train accuracy 0.99| Test accuracy 0.86| Test loss 0.77
# epoch (198)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.86| Test loss 0.78
# epoch (199)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.74
# epoch (200)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.86| Test loss 0.78
# epoch (201)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.74
# epoch (202)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.86| Test loss 0.78
# epoch (203)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.86| Test loss 0.83
# epoch (204)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.86| Test loss 0.78
# epoch (205)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.77
# epoch (206)| Train loss 0.01| Train accuracy 0.99| Test accuracy 0.87| Test loss 0.78
# epoch (207)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.78
# epoch (208)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.79
# epoch (209)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.79
# Saving model...
# epoch (210)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.77
# epoch (211)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.75
# Saving model...
# epoch (212)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.78
# epoch (213)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.86| Test loss 0.8
# epoch (214)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.86| Test loss 0.78
# epoch (215)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.78
# epoch (216)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.76
# epoch (217)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.75
# epoch (218)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.86| Test loss 0.83
# epoch (219)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.78
# epoch (220)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (221)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (222)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.76
# Saving model...
# epoch (223)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.77
# epoch (224)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.78
# epoch (225)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.78
# epoch (226)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.77
# epoch (227)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.78
# epoch (228)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.78
# Saving model...
# epoch (229)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.86| Test loss 0.79
# epoch (230)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.79
# epoch (231)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (232)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.79
# epoch (233)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (234)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (235)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (236)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (237)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.82
# epoch (238)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (239)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (240)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (241)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.82
# epoch (242)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.79
# epoch (243)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.82
# epoch (244)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (245)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (246)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (247)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (248)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (249)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (250)| Train loss 0.01| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (251)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (252)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (253)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.79
# epoch (254)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (255)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (256)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.84
# epoch (257)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.82
# epoch (258)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (259)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.81
# Saving model...
# epoch (260)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (261)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (262)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (263)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (264)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (265)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.82
# epoch (266)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (267)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (268)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (269)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (270)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.78
# epoch (271)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (272)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.8
# epoch (273)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (274)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.81
# epoch (275)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.81
# Saving model...
# epoch (276)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (277)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.82
# epoch (278)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (279)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (280)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.82
# epoch (281)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.84
# epoch (282)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.82
# epoch (283)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.84
# epoch (284)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.85
# epoch (285)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (286)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (287)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (288)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (289)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (290)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.82
# epoch (291)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# Saving model...
# epoch (292)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (293)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (294)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.84
# epoch (295)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (296)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (297)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.84
# epoch (298)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (299)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (300)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (301)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# Saving model...
# epoch (302)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (303)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (304)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (305)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (306)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (307)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (308)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (309)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (310)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (311)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (312)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.83
# epoch (313)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (314)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.87| Test loss 0.82
# epoch (315)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (316)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (317)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# Saving model...
# epoch (318)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (319)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (320)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (321)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (322)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# Saving model...
# epoch (323)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (324)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (325)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (326)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (327)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (328)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (329)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (330)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (331)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# Saving model...
# epoch (332)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (333)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# Saving model...
# epoch (334)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# Saving model...
# epoch (335)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# Saving model...
# epoch (336)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (337)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (338)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (339)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (340)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (341)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (342)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.83
# epoch (343)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (344)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (345)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (346)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (347)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (348)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (349)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82
# epoch (350)| Train loss 0.0| Train accuracy 1.0| Test accuracy 0.88| Test loss 0.82

# %%
net.load_state_dict(torch.load('./models/x_ray_victim.ckpt')['net'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 net.load_state_dict(torch.load('./models/x_ray_victim.ckpt')['net'])
#
# NameError: name 'net' is not defined

# %%
preds, labels = get_preds_labels(net, test_loader, device)

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

def roc_curve_ood(preds, labels):
    fpr, tpr, thresholds = roc_curve(labels, preds)
    thres_idx = np.argmin(np.square(tpr-0.95))
    thres95 = thresholds[thres_idx]
    auc_score = roc_auc_score(labels, preds)
    return thres95, auc_score


thres95, auc = roc_curve_ood(preds, labels)
print(f'AUROC: {auc}')

# %% [markdown]
# ### Adversarial attack(un-adaptive)

# %%
def GradientPGDAttack(model, inputs, labels,
                                   loss_func, eps, device):
    pertubation = torch.zeros(inputs.size()).to(device)
    samples = inputs.to(device)
    for i in range(50):
        pertubation = torch.autograd.Variable(pertubation, requires_grad=True)
        classifer_outputs = model((samples+pertubation))
        classifier_labels = labels.to(device)
        loss = loss_func(classifer_outputs, classifier_labels)
        loss.backward()
        gradient = torch.ge(pertubation.grad.data, 0)
        pertubation = torch.add(pertubation.data, +(eps/10)*gradient).detach()    
        pertubation = torch.clamp(pertubation, min = -eps, max= eps)
        del classifer_outputs, classifier_labels, gradient, loss
    return (samples+pertubation)

def gen_adv_dataset(model, loader, eps):
    data = []
    labels = []
    for samples, targets in loader:
        labels.append(targets)
        samples, targets = samples.to(device), targets.to(device)

        pertubed = GradientPGDAttack(model, samples, targets,
                                  BinaryCrossEntropy(),
                                  eps, device).detach().cpu()
        data.append(pertubed)
    data = torch.cat(data)
    labels = torch.cat(labels)
    dataset = torch.utils.data.TensorDataset(data, labels)
    return torch.utils.data.DataLoader(dataset, batch_size=128,
                      shuffle=False,num_workers =6,pin_memory = True)

# %%
adv_dataloader = gen_adv_dataset(net, test_loader, 8/255)

# %%
preds, labels = get_preds_labels(net, adv_dataloader, device)
thres95, auc = roc_curve_ood(preds, labels)
print(f'AUROC: {auc}')

# %% [markdown]
# # MGM

# %%
from sklearn.metrics import roc_auc_score
from sklearn import metrics

# %%
def net_pen_rep(net, x):
    out = net.conv1(x)
    out = net.bn1(out)
    out = net.relu(out)
    out = net.layer1(out)
    out = net.layer2(out)
    out = net.layer3(out)
    out = net.layer4(out)
    out = net.avgpool(out)
    return out

def get_pen_reps(net, loader, device):
    net.eval()
    reps = []
    with torch.no_grad():
        for (inputs, targets) in loader:
            inputs= inputs.to(device)
            input_reps = net_pen_rep(net, inputs)
            input_reps = input_reps.detach().cpu()
            reps.append(input_reps)
        reps = torch.cat(reps).squeeze()
        return reps    
    
def calc_MGM_params(net, trainloader):
    train_reps = get_pen_reps(net,
                              trainloader,
                              device).t()
    m = train_reps.size(1) 
    f_dim = train_reps.size(0)
    mu = train_reps.mean(dim = 1,  keepdim=True)
    train_reps -= mu
    cov = (1/ (m+1)) * train_reps.matmul(train_reps.t()) +1e-10*torch.eye(f_dim, f_dim)
    R = torch.cholesky(cov, upper=False)
    R_diag_sum = R.diag().sum()
    R_inv = torch.cholesky_inverse(R)
    return f_dim, R_diag_sum, R_inv, mu
    
def calc_likelihood(rep, f_dim, R_diag_sum, R_inv, mu):
    Z = -0.5*R_diag_sum -f_dim*np.log(2*np.pi)
    log_exp = (R_inv.matmul(rep - mu)**2).sum(dim=0)
    return Z+log_exp
    
def predict_liklihood(net, loader,f_dim, R_diag_sum, R_inv, mu):
    net.eval()
    preds = []
    with torch.no_grad():
        for (inputs, targets) in loader:
            inputs= inputs.to(device)
            reps = net_pen_rep(net, inputs)
            reps = reps.detach().cpu()
            pred = calc_likelihood(reps.squeeze().t(), f_dim, 
                                   R_diag_sum, R_inv, mu)
            preds.append(pred)
        preds = torch.cat(preds)
    return preds

# %%
f_dim, R_diag_sum, R_inv, mu = calc_MGM_params(net, train_loader)

# %%
adv_likelihood = predict_liklihood(net, adv_dataloader, f_dim, R_diag_sum, R_inv, mu)
bengin_likelihood = predict_liklihood(net, test_loader, f_dim, R_diag_sum, R_inv, mu)

# %%
plt.hist(adv_likelihood.numpy(), bins=100, color='r')
plt.hist(bengin_likelihood.numpy(), bins=100, color='b')
plt.show()
